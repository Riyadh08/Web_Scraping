# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Function to fetch the list URLs from a single page of the "Recently Active Lists"
def fetch_list_urls(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    # Send a GET request to the Goodreads page
    response = requests.get(url, headers=headers)
    
    # Check if the response is OK (status code 200)
    if response.status_code != 200:
        print(f"Failed to retrieve the webpage: {url}")
        return []
    
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the list containers and their respective URLs
    list_urls = []
    for list_container in soup.find_all('a', class_='listTitle'):
        list_name = list_container.get_text(strip=True)
        list_url = 'https://www.goodreads.com' + list_container['href']  # Construct the full URL
        list_urls.append((list_name, list_url))
    
    return list_urls

# Function to fetch book titles from a given list URL
def fetch_books_from_list(list_name, list_url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    response = requests.get(list_url, headers=headers)
    
    if response.status_code != 200:
        print(f"Failed to retrieve the list: {list_url}")
        return []
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all book titles in the list
    book_titles = []
    for book in soup.find_all('a', class_='bookTitle'):
        book_title = book.get_text(strip=True)
        book_titles.append(book_title)
    
    return book_titles

# Function to scrape list URLs and then scrape books from those lists
def scrape_lists(base_url, total_pages):
    all_books = []
    
    for page_num in range(1, total_pages + 1):
        url = f"{base_url}{page_num}"
        print(f"Scraping page {page_num}: {url}")
        
        # Fetch list URLs from the current page
        list_urls = fetch_list_urls(url)
        
        if list_urls:
            for list_name, list_url in list_urls:
                print(f"Fetching books from list: {list_name} ({list_url})")
                
                # Fetch books from the list
                books = fetch_books_from_list(list_name, list_url)
                all_books.extend([(list_name, book) for book in books])
        else:
            print(f"No lists found on page {page_num}")
        
        # Pause to avoid overwhelming the server
        time.sleep(2)
    
    return all_books

# Function to save titles to a CSV file using pandas
def save_to_csv(book_data, filename):
    # Create a pandas DataFrame from the list of (list_name, book_title)
    df = pd.DataFrame(book_data, columns=['List Name', 'Book Title'])
    
    # Save the DataFrame to a CSV file
    df.to_csv(filename, index=False)

# Base URL of the Goodreads "Recently Active Lists" with pagination
base_url = 'https://www.goodreads.com/list/recently_active_lists?page='

# Total number of pages to scrape (1 to 100)
total_pages = 10

# Scrape book titles from the first 100 pages
book_data = scrape_lists(base_url, total_pages)

# Saving titles to a CSV file if any books are found
if book_data:
    save_to_csv(book_data, 'goodreads_recently_active_books.csv')
    print(f'Successfully saved {len(book_data)} books to CSV file.')
else:
    print("No books were scraped.")
# Out:
# Scraping page 1: https://www.goodreads.com/list/recently_active_lists?page=1
# Fetching books from list: Good Novels With Regretful Heroes (https://www.goodreads.com/list/show/121977.Good_Novels_With_Regretful_Heroes)
# Fetching books from list: 100 Books to Read in a Lifetime: Readers' Picks (https://www.goodreads.com/list/show/69635.100_Books_to_Read_in_a_Lifetime_Readers_Picks)
# Fetching books from list: Christmas Wish List (https://www.goodreads.com/list/show/28467.Christmas_Wish_List)
# Fetching books from list: MUST READS!!! (https://www.goodreads.com/list/show/19106.MUST_READS_)
# Fetching books from list: Christmas Stocking Stuffers (https://www.goodreads.com/list/show/14962.Christmas_Stocking_Stuffers)
# Fetching books from list: Books That Should Be Made Into Movies (https://www.goodreads.com/list/show/1043.Books_That_Should_Be_Made_Into_Movies)
# Fetching books from list: BookTok Romance Recommendations (https://www.goodreads.com/list/show/168061.BookTok_Romance_Recommendations)
# Fetching books from list: Best Books to Read When the Snow Is Falling (https://www.goodreads.com/list/show/23652.Best_Books_to_Read_When_the_Snow_Is_Falling)
# Fetching books from list: Books That Everyone Should Read At Least Once (https://www.goodreads.com/list/show/264.Books_That_Everyone_Should_Read_At_Least_Once)
# Fetching books from list: [ATY 2025] Digging Up the Past (https://www.goodreads.com/list/show/218519._ATY_2025_Digging_Up_the_Past)
# Scraping page 2: https://www.goodreads.com/list/recently_active_lists?page=2
# Fetching books from list: [ATY 2025] Digging Up the Past (https://www.goodreads.com/list/show/218519._ATY_2025_Digging_Up_the_Past)
# Fetching books from list: Bad Mothers (https://www.goodreads.com/list/show/137468.Bad_Mothers_)
# Fetching books from list: September 2024 Most Anticipated Romance Releases (https://www.goodreads.com/list/show/198334.September_2024_Most_Anticipated_Romance_Releases)
# Fetching books from list: Books That Were Way Better Than I Thought They Would Be (https://www.goodreads.com/list/show/16688.Books_That_Were_Way_Better_Than_I_Thought_They_Would_Be)
# Fetching books from list: Best Books To Gift (https://www.goodreads.com/list/show/7623.Best_Books_To_Gift)
# Fetching books from list: Best Ebooks To Give As Gifts (https://www.goodreads.com/list/show/15133.Best_Ebooks_To_Give_As_Gifts)
# Fetching books from list: Indie-ish Memoirs That Deserve More Attention (https://www.goodreads.com/list/show/218631.Indie_ish_Memoirs_That_Deserve_More_Attention)
# Fetching books from list: The Most Disturbing Books Ever Written (https://www.goodreads.com/list/show/2455.The_Most_Disturbing_Books_Ever_Written)
# Fetching books from list: The Best Epic Fantasy (fiction) (https://www.goodreads.com/list/show/50.The_Best_Epic_Fantasy_fiction_)
# Fetching books from list: [ATY 2025] Set in Winter (https://www.goodreads.com/list/show/218518._ATY_2025_Set_in_Winter)
# Scraping page 3: https://www.goodreads.com/list/recently_active_lists?page=3
# Fetching books from list: The Best Epic Fantasy (fiction) (https://www.goodreads.com/list/show/50.The_Best_Epic_Fantasy_fiction_)
# Fetching books from list: [ATY 2025] Set in Winter (https://www.goodreads.com/list/show/218518._ATY_2025_Set_in_Winter)
# Fetching books from list: Books I Will Never Forget (https://www.goodreads.com/list/show/3555.Books_I_Will_Never_Forget)
# Fetching books from list: 2025 Contemporary Romance Releases (https://www.goodreads.com/list/show/190030.2025_Contemporary_Romance_Releases)
# Fetching books from list: Original Stories . . . a Breath of Fresh Air (https://www.goodreads.com/list/show/7057.Original_Stories_a_Breath_of_Fresh_Air)
# Fetching books from list: Favorite Books (https://www.goodreads.com/list/show/63.Favorite_Books)
# Fetching books from list: Space Opera Fans Favorites (https://www.goodreads.com/list/show/72626.Space_Opera_Fans_Favorites)
# Fetching books from list: Best Crime & Mystery Books (https://www.goodreads.com/list/show/11.Best_Crime_Mystery_Books)
# Fetching books from list: Books you have read more than one time (https://www.goodreads.com/list/show/9357.Books_you_have_read_more_than_one_time)
# Fetching books from list: Read Them Twice...At Least (https://www.goodreads.com/list/show/474.Read_Them_Twice_At_Least)
# Scraping page 4: https://www.goodreads.com/list/recently_active_lists?page=4
# Fetching books from list: Books I Became So Obsessed With I Stopped Everything Else in My Life to Finish. (https://www.goodreads.com/list/show/5539.Books_I_Became_So_Obsessed_With_I_Stopped_Everything_Else_in_My_Life_to_Finish_)
# Fetching books from list: Best for Book Clubs (https://www.goodreads.com/list/show/19.Best_for_Book_Clubs)
# Fetching books from list: 2024: What Women Born In The 1970s Have Read So Far This Year (https://www.goodreads.com/list/show/196220.2024_What_Women_Born_In_The_1970s_Have_Read_So_Far_This_Year)
# Fetching books from list: Best Reads of the Holiday Season (https://www.goodreads.com/list/show/14116.Best_Reads_of_the_Holiday_Season)
# Fetching books from list: Best Ending (https://www.goodreads.com/list/show/574.Best_Ending)
# Fetching books from list: Best Japanese Books (https://www.goodreads.com/list/show/32.Best_Japanese_Books)
# Fetching books from list: Best Christmas guilty pleasures (https://www.goodreads.com/list/show/14198.Best_Christmas_guilty_pleasures)
# Fetching books from list: Must Read Books- Different Genres (https://www.goodreads.com/list/show/2491.Must_Read_Books_Different_Genres)
# Fetching books from list: Best Literary Mysteries (https://www.goodreads.com/list/show/914.Best_Literary_Mysteries)
# Fetching books from list: Best Modern Mystery, Crime fiction (https://www.goodreads.com/list/show/3919.Best_Modern_Mystery_Crime_fiction)
# Scraping page 5: https://www.goodreads.com/list/recently_active_lists?page=5
# Fetching books from list: Christmas Break (https://www.goodreads.com/list/show/80253.Christmas_Break)
# Fetching books from list: Contemporary Gift Book Ideas (https://www.goodreads.com/list/show/7661.Contemporary_Gift_Book_Ideas)
# Fetching books from list: Christmas List (https://www.goodreads.com/list/show/28663.Christmas_List)
# Fetching books from list: Holidays (https://www.goodreads.com/list/show/15572.Holidays)
# Fetching books from list: Books You Would Recommend to Strangers (https://www.goodreads.com/list/show/2997.Books_You_Would_Recommend_to_Strangers)
# Fetching books from list: Christmas/Birthday gift (https://www.goodreads.com/list/show/6754.Christmas_Birthday_gift)
# Fetching books from list: Books You Could Not Put Down (https://www.goodreads.com/list/show/1657.Books_You_Could_Not_Put_Down)
# Fetching books from list: Yuletide Reads (https://www.goodreads.com/list/show/42865.Yuletide_Reads)
# Fetching books from list: Reportaż - Wydawnictwo Czarne (https://www.goodreads.com/list/show/176963.Reporta_Wydawnictwo_Czarne)
# Fetching books from list: Books with a VHS Tape for a Front Cover (https://www.goodreads.com/list/show/107189.Books_with_a_VHS_Tape_for_a_Front_Cover)
# Scraping page 6: https://www.goodreads.com/list/recently_active_lists?page=6
# Fetching books from list: Books with a VHS Tape for a Front Cover (https://www.goodreads.com/list/show/107189.Books_with_a_VHS_Tape_for_a_Front_Cover)
# Fetching books from list: Favourite Crime & Thrillers (https://www.goodreads.com/list/show/12089.Favourite_Crime_Thrillers)
# Fetching books from list: Couldn't Put The Book Down (https://www.goodreads.com/list/show/2994.Couldn_t_Put_The_Book_Down_)
# Fetching books from list: Asian Lesbian and Queer Women Fiction (https://www.goodreads.com/list/show/30043.Asian_Lesbian_and_Queer_Women_Fiction)
# Fetching books from list: Thrillers You Must Read! (https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_)
# Fetching books from list: Off the beaten path holiday books (https://www.goodreads.com/list/show/81929.Off_the_beaten_path_holiday_books)
# Fetching books from list: I Wish I Could Read it Again for the First Time (https://www.goodreads.com/list/show/2816.I_Wish_I_Could_Read_it_Again_for_the_First_Time)
# Fetching books from list: Books that Blew Me Away and that I Still Think About (https://www.goodreads.com/list/show/2386.Books_that_Blew_Me_Away_and_that_I_Still_Think_About_)
# Fetching books from list: Beach Reads - Mysteries & Thrillers (https://www.goodreads.com/list/show/10997.Beach_Reads_Mysteries_Thrillers)
# Fetching books from list: [ATY 2025] Do Re Mi (https://www.goodreads.com/list/show/218333._ATY_2025_Do_Re_Mi)
# Scraping page 7: https://www.goodreads.com/list/recently_active_lists?page=7
# Fetching books from list: [ATY 2025] Do Re Mi (https://www.goodreads.com/list/show/218333._ATY_2025_Do_Re_Mi)
# Fetching books from list: Can't Wait Sci-Fi/Fantasy of 2025 (https://www.goodreads.com/list/show/204763.Can_t_Wait_Sci_Fi_Fantasy_of_2025)
# Fetching books from list: [ATY 2025] NPR's Books We Love (https://www.goodreads.com/list/show/218334._ATY_2025_NPR_s_Books_We_Love)
# Fetching books from list: Thrillers (https://www.goodreads.com/list/show/348.Thrillers)
# Fetching books from list: [ATY 2025] Related to a Collective Noun for Animals (https://www.goodreads.com/list/show/212348._ATY_2025_Related_to_a_Collective_Noun_for_Animals)
# Fetching books from list: [ATY 2025] Irish Author (https://www.goodreads.com/list/show/218520._ATY_2025_Irish_Author)
# Fetching books from list: Kindle reads for Christmas (https://www.goodreads.com/list/show/7414.Kindle_reads_for_Christmas)
# Fetching books from list: [ATY 2025] Adult Friendships (https://www.goodreads.com/list/show/214040._ATY_2025_Adult_Friendships)
# Fetching books from list: Pretty Girls Horror (https://www.goodreads.com/list/show/198244.Pretty_Girls_Horror)
# Fetching books from list: Young Adult Romance (https://www.goodreads.com/list/show/1333.Young_Adult_Romance)
# Scraping page 8: https://www.goodreads.com/list/recently_active_lists?page=8
# Fetching books from list: [ATY 2025] Translated Novel from Asia (https://www.goodreads.com/list/show/218335._ATY_2025_Translated_Novel_from_Asia)
# Fetching books from list: [ATY 2025] Coastal Setting (https://www.goodreads.com/list/show/206388._ATY_2025_Coastal_Setting)
# Fetching books from list: [ATY 2025] Haunting Book (https://www.goodreads.com/list/show/204360._ATY_2025_Haunting_Book)
# Fetching books from list: Ten Best Crime/Mystery/Thrillers (https://www.goodreads.com/list/show/19734.Ten_Best_Crime_Mystery_Thrillers)
# Fetching books from list: [ATY 2025] Centered around Secrets, Lies, or Deception (https://www.goodreads.com/list/show/204865._ATY_2025_Centered_around_Secrets_Lies_or_Deception)
# Fetching books from list: [ATY 2025] Country Song Title (https://www.goodreads.com/list/show/205069._ATY_2025_Country_Song_Title)
# Fetching books from list: [ATY 2025] Fire! (https://www.goodreads.com/list/show/218331._ATY_2025_Fire_)
# Fetching books from list: [ATY 2025] Time Travel, Alternate Universes, Alternate Timelines (https://www.goodreads.com/list/show/204571._ATY_2025_Time_Travel_Alternate_Universes_Alternate_Timelines)
# Fetching books from list: Shadow Daddy (https://www.goodreads.com/list/show/190920.Shadow_Daddy)
# Fetching books from list: Best "Strong Female" Fantasy Novels (https://www.goodreads.com/list/show/1023.Best_Strong_Female_Fantasy_Novels)
# Scraping page 9: https://www.goodreads.com/list/recently_active_lists?page=9
# Fetching books from list: 52 Book Club 2024: #52 Published In 2024 (https://www.goodreads.com/list/show/193053.52_Book_Club_2024_52_Published_In_2024)
# Fetching books from list: Best Thrillers (https://www.goodreads.com/list/show/1112.Best_Thrillers)
# Fetching books from list: autumn, spooky themed middle grade books (https://www.goodreads.com/list/show/218652.autumn_spooky_themed_middle_grade_books)
# Fetching books from list: [ATY 2025] Waves on Cover (https://www.goodreads.com/list/show/204358._ATY_2025_Waves_on_Cover)
# Fetching books from list: [ATY 2025] Science Fiction or Fantasy by a Woman (https://www.goodreads.com/list/show/203218._ATY_2025_Science_Fiction_or_Fantasy_by_a_Woman)
# Fetching books from list: Books=Gifts (https://www.goodreads.com/list/show/1201.Books_Gifts)
# Fetching books from list: "Girls only" (https://www.goodreads.com/list/show/218651._Girls_only_)
# Fetching books from list: Unforgettables (https://www.goodreads.com/list/show/592.Unforgettables)
# Fetching books from list: Best Books of 2024 (https://www.goodreads.com/list/show/196307.Best_Books_of_2024)
# Fetching books from list: Winter Seasonal Reads (https://www.goodreads.com/list/show/126979.Winter_Seasonal_Reads_)
# Scraping page 10: https://www.goodreads.com/list/recently_active_lists?page=10
# Fetching books from list: Elizabeth's Books (https://www.goodreads.com/list/show/218650.Elizabeth_s_Books)
# Fetching books from list: Picture Books About Outstanding Women (https://www.goodreads.com/list/show/75269.Picture_Books_About_Outstanding_Women)
# Fetching books from list: Greek Mythology Retellings! (https://www.goodreads.com/list/show/162452.Greek_Mythology_Retellings_)
# Fetching books from list: Cassandra of Troy (https://www.goodreads.com/list/show/186541.Cassandra_of_Troy)
# Fetching books from list: [ATY 2025] Dealing with Death (https://www.goodreads.com/list/show/212341._ATY_2025_Dealing_with_Death)
# Fetching books from list: Simon Mayo's Books Of The Year - 2024 (https://www.goodreads.com/list/show/196818.Simon_Mayo_s_Books_Of_The_Year_2024)
# Fetching books from list: [ATY 2025] Cityscape or Building on Cover (https://www.goodreads.com/list/show/206392._ATY_2025_Cityscape_or_Building_on_Cover)
# Fetching books from list: Best eco-fiction (https://www.goodreads.com/list/show/12043.Best_eco_fiction)
# Fetching books from list: [ATY 2025] Sunset Vibes on Cover (https://www.goodreads.com/list/show/206389._ATY_2025_Sunset_Vibes_on_Cover)
# Fetching books from list: [ATY 2025] Group That Isn't a Family (https://www.goodreads.com/list/show/205068._ATY_2025_Group_That_Isn_t_a_Family)
# Successfully saved 9136 books to CSV file.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Function to fetch the list URLs from a single page of the "Recently Active Lists"
def fetch_list_urls(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    # Send a GET request to the Goodreads page
    response = requests.get(url, headers=headers)
    
    # Check if the response is OK (status code 200)
    if response.status_code != 200:
        print(f"Failed to retrieve the webpage: {url}")
        return []
    
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the list containers and their respective URLs
    list_urls = []
    for list_container in soup.find_all('a', class_='listTitle'):
        list_name = list_container.get_text(strip=True)
        list_url = 'https://www.goodreads.com' + list_container['href']  # Construct the full URL
        list_urls.append((list_name, list_url))
    
    return list_urls

# Function to fetch book titles and user ratings from a given list URL
def fetch_books_from_list(list_name, list_url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    response = requests.get(list_url, headers=headers)
    
    if response.status_code != 200:
        print(f"Failed to retrieve the list: {list_url}")
        return []
    
    # Print the HTML content for debugging purposes
    print(f"Fetching books from list: {list_name} ({list_url})")
    print(response.content[:1000])  # Print the first 1000 characters of the HTML content
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all book titles and user ratings in the list
    book_data = []
    
    # Debugging: Check if class names are correct
    for book_item in soup.find_all('tr', class_='bookalike'):
        book_title = book_item.find('a', class_='bookTitle').get_text(strip=True)
        
        # Find the user rating
        rating_tag = book_item.find('span', class_='minirating')
        if rating_tag:
            user_rating = rating_tag.get_text(strip=True)
        else:
            user_rating = "No rating"
        
        book_data.append((list_name, book_title, user_rating))
    
    return book_data

# Function to scrape list URLs and then scrape books from those lists
def scrape_lists(base_url, total_pages):
    all_books = []
    
    for page_num in range(1, total_pages + 1):
        url = f"{base_url}{page_num}"
        print(f"Scraping page {page_num}: {url}")
        
        # Fetch list URLs from the current page
        list_urls = fetch_list_urls(url)
        
        if list_urls:
            for list_name, list_url in list_urls:
                print(f"Fetching books from list: {list_name} ({list_url})")
                
                # Fetch books and ratings from the list
                books = fetch_books_from_list(list_name, list_url)
                all_books.extend(books)
        else:
            print(f"No lists found on page {page_num}")
        
        # Pause to avoid overwhelming the server
        time.sleep(2)
    
    return all_books

# Function to save titles and ratings to a CSV file using pandas
def save_to_csv(book_data, filename):
    # Create a pandas DataFrame from the list of (list_name, book_title, user_rating)
    df = pd.DataFrame(book_data, columns=['List Name', 'Book Title', 'User Rating'])
    
    # Save the DataFrame to a CSV file
    df.to_csv(filename, index=False)

# Base URL of the Goodreads "Recently Active Lists" with pagination
base_url = 'https://www.goodreads.com/list/recently_active_lists?page='

# Total number of pages to scrape (1 to 4 for testing)
total_pages = 4

# Scrape book titles and ratings from the first 100 pages
book_data = scrape_lists(base_url, total_pages)

# Saving titles and ratings to a CSV file if any books are found
if book_data:
    save_to_csv(book_data, 'goodreads_recently_active_books_with_ratings.csv')
    print(f'Successfully saved {len(book_data)} books and ratings to CSV file.')
else:
    print("No books were scraped.")
# Out:
# Scraping page 1: https://www.goodreads.com/list/recently_active_lists?page=1
# Fetching books from list: Christmas Fantasy Wish List (https://www.goodreads.com/list/show/15150.Christmas_Fantasy_Wish_List)
# Fetching books from list: Christmas Fantasy Wish List (https://www.goodreads.com/list/show/15150.Christmas_Fantasy_Wish_List)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Christmas Fantasy Wish List (3388 books)</title>\n\n<meta content="3,388 books based on 202 votes: A Wrinkle in Time by Madeleine L\'Engle, The Lion, the Witch and the Wardrobe by C.S. Lewis, In a Holidaze by Christina La..." name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/list/show/15150.Christmas_Fantasy_Wish_List\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "573-9176181-6980477";\n    var ue_id = "F4A28XZ2CN8BG7K33VWK";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:argument'
# Fetching books from list: Best Ending (https://www.goodreads.com/list/show/574.Best_Ending)
# Fetching books from list: Best Ending (https://www.goodreads.com/list/show/574.Best_Ending)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Best Ending (7226 books)</title>\n\n<meta content=\'7,226 books based on 5419 votes: Harry Potter and the Deathly Hallows by J.K. Rowling, Pride and Prejudice by Jane Austen, 1984 by George Orwell, Ender\xe2\x80\x99s...\' name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/list/show/574.Best_Ending\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "990-7385468-3437329";\n    var ue_id = "1ENMMCS8N4YKBFTCBTG7";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,'
# Fetching books from list: Must Read Books- Different Genres (https://www.goodreads.com/list/show/2491.Must_Read_Books_Different_Genres)
# Fetching books from list: Must Read Books- Different Genres (https://www.goodreads.com/list/show/2491.Must_Read_Books_Different_Genres)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Must Read Books- Different Genres (12394 books)</title>\n\n<meta content=\'12,389 books based on 8839 votes: The Hunger Games by Suzanne Collins, Catching Fire by Suzanne Collins, Harry Potter Series Box Set by J.K. Rowling, Moc...\' name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/list/show/2491.Must_Read_Books_Different_Genres\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "418-6924053-9968208";\n    var ue_id = "MHBWRZB4Z2E0K2F5KTP7";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h'
# Fetching books from list: Books That Exceeded Your Expectations (https://www.goodreads.com/list/show/423.Books_That_Exceeded_Your_Expectations)
# Fetching books from list: Books That Exceeded Your Expectations (https://www.goodreads.com/list/show/423.Books_That_Exceeded_Your_Expectations)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Books That Exceeded Your Expectations (13303 books)</title>\n\n<meta content=\'13,293 books based on 14787 votes: The Hunger Games by Suzanne Collins, The Book Thief by Markus Zusak, The Kite Runner by Khaled Hosseini, Harry Potter ...\' name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/list/show/423.Books_That_Exceeded_Your_Expectations\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "981-4085270-6205837";\n    var ue_id = "PJF3XKRRJHE6MKK75DN1";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.p'
# Fetching books from list: Best Books Ever (https://www.goodreads.com/list/show/1.Best_Books_Ever)
# Fetching books from list: Best Books Ever (https://www.goodreads.com/list/show/1.Best_Books_Ever)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Best Books Ever (125309 books)</title>\n\n<meta content=\'123,816 books based on 262856 votes: The Hunger Games by Suzanne Collins, Harry Potter and the Order of the Phoenix by J.K. Rowling, Pride and Prejudice ...\' name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/list/show/1.Best_Books_Ever\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "605-2869628-8443737";\n    var ue_id = "GNMDFFH8T6N6C8AHY6NZ";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,'
# Fetching books from list: READ IT OVER AND OVER AGAIN! (https://www.goodreads.com/list/show/14227.READ_IT_OVER_AND_OVER_AGAIN_)
# Fetching books from list: READ IT OVER AND OVER AGAIN! (https://www.goodreads.com/list/show/14227.READ_IT_OVER_AND_OVER_AGAIN_)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>READ IT OVER AND OVER AGAIN! (9818 books)</title>\n\n<meta content=\'9,818 books based on 6077 votes: Beautiful Disaster by Jamie McGuire, The Hunger Games by Suzanne Collins, Fifty Shades of Grey by E.L. James, Twilight b...\' name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/list/show/14227.READ_IT_OVER_AND_OVER_AGAIN_\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "031-4360827-7861996";\n    var ue_id = "3BXSSKAXMQA7S2K5EQ93";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:argume'
# Fetching books from list: Kindle reads for Christmas (https://www.goodreads.com/list/show/7414.Kindle_reads_for_Christmas)
# Fetching books from list: Kindle reads for Christmas (https://www.goodreads.com/list/show/7414.Kindle_reads_for_Christmas)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Kindle reads for Christmas (4079 books)</title>\n\n<meta content=\'4,079 books based on 429 votes: Yuletide Tales A Festive Collective by Peter John, Gods of Another Kind by Steven Decker, Being a Witch, and Other Things...\' name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/list/show/7414.Kindle_reads_for_Christmas\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "797-0697806-3026293";\n    var ue_id = "75W0GSXR7V5VDV7DZS1G";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t'
# Fetching books from list: The Best Urban Fantasy (https://www.goodreads.com/list/show/51.The_Best_Urban_Fantasy)
# Fetching books from list: The Best Urban Fantasy (https://www.goodreads.com/list/show/51.The_Best_Urban_Fantasy)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>The Best Urban Fantasy (4254 books)</title>\n\n<meta content="4,256 books based on 13167 votes: City of Bones by Cassandra Clare, Moon Called by Patricia Briggs, Harry Potter and the Sorcerer\'s Stone by J.K. Rowling..." name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/list/show/51.The_Best_Urban_Fantasy\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "033-3391281-7879077";\n    var ue_id = "50TFMTB31TNAXWVE5ZGQ";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}'
# Fetching books from list: Books That Everyone Should Read At Least Once (https://www.goodreads.com/list/show/264.Books_That_Everyone_Should_Read_At_Least_Once)
# Fetching books from list: Books That Everyone Should Read At Least Once (https://www.goodreads.com/list/show/264.Books_That_Everyone_Should_Read_At_Least_Once)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Books That Everyone Should Read At Least Once (33076 books)</title>\n\n<meta content=\'32,746 books based on 111959 votes: To Kill a Mockingbird by Harper Lee, Harry Potter and the Sorcerer\xe2\x80\x99s Stone by J.K. Rowling, Pride and Prejudice by Ja...\' name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/list/show/264.Books_That_Everyone_Should_Read_At_Least_Once\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "143-8431393-7273651";\n    var ue_id = "DZSAFZZ2T17E6MK489EK";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){retur'
# Fetching books from list: Most Popular Books on Goodreads (https://www.goodreads.com/list/show/154948.Most_Popular_Books_on_Goodreads)
# Fetching books from list: Most Popular Books on Goodreads (https://www.goodreads.com/list/show/154948.Most_Popular_Books_on_Goodreads)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Most Popular Books on Goodreads (87 books)</title>\n\n<meta content="87 books based on 34 votes: Harry Potter and the Sorcerer\'s Stone by J.K. Rowling, The Fault in Our Stars by John Green, Mockingjay by Suzanne Collins, T..." name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/list/show/154948.Most_Popular_Books_on_Goodreads\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "048-6294248-4861554";\n    var ue_id = "FZHJAG3RX4DBWGDHS6XS";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:a'
# Scraping page 2: https://www.goodreads.com/list/recently_active_lists?page=2
# Fetching books from list: Best Gothic Books of All Time (https://www.goodreads.com/list/show/1230.Best_Gothic_Books_of_All_Time)
# Fetching books from list: Best Gothic Books of All Time (https://www.goodreads.com/list/show/1230.Best_Gothic_Books_of_All_Time)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Best Gothic Books of All Time (548 books)</title>\n\n<meta content=\'549 books based on 3906 votes: Jane Eyre by Charlotte Bront\xc3\xab, Frankenstein: The 1818 Text by Mary Wollstonecraft Shelley, Wuthering Heights by Emily Bron...\' name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/list/show/1230.Best_Gothic_Books_of_All_Time\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "080-3415733-7705985";\n    var ue_id = "0A97812E2EMYPWT9SA7Z";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a
\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.'
# Fetching books from list: Best Reads of the Holiday Season (https://www.goodreads.com/list/show/14116.Best_Reads_of_the_Holiday_Season)
# Fetching books from list: Best Reads of the Holiday Season (https://www.goodreads.com/list/show/14116.Best_Reads_of_the_Holiday_Season)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Best Reads of the Holiday Season (3996 books)</title>\n\n<meta content=\'3,996 books based on 578 votes: A Christmas Carol by Charles Dickens, How the Grinch Stole Christmas! by Dr. Seuss, The Polar Express by Chris Van Allsbu...\' name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/list/show/14116.Best_Reads_of_the_Holiday_Season\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "202-0258266-8522388";\n    var ue_id = "E1X0W6NFVE4MTCY701DH";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,'
# Fetching books from list: Best Literature About the Vietnam War (https://www.goodreads.com/list/show/208.Best_Literature_About_the_Vietnam_War)
# Fetching books from list: Best Literature About the Vietnam War (https://www.goodreads.com/list/show/208.Best_Literature_About_the_Vietnam_War)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Best Literature About the Vietnam War (328 books)</title>\n\n<meta content="328 books based on 637 votes: The Things They Carried by Tim O\'Brien, Matterhorn by Karl Marlantes, Dispatches by Michael Herr, A Rumor of War by Philip ..." name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/list/show/208.Best_Literature_About_the_Vietnam_War\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "322-9220600-9509231";\n    var ue_id = "PN7JA23RZFS1F9ZMYN8T";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.pus'
# Fetching books from list: Best for Book Clubs (https://www.goodreads.com/list/show/19.Best_for_Book_Clubs)
# Fetching books from list: Best for Book Clubs (https://www.goodreads.com/list/show/19.Best_for_Book_Clubs)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Best for Book Clubs (13189 books)</title>\n\n<meta content=\'13,189 books based on 17785 votes: The Help by Kathryn Stockett, The Kite Runner by Khaled Hosseini, Water for Elephants by Sara Gruen, The Book Thief by...\' name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/list/show/19.Best_for_Book_Clubs\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "925-9883239-8142228";\n    var ue_id = "N3QEFAMPNS2SN90JXCN1";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}funct'
# Fetching books from list: Best Books of the 21st Century (https://www.goodreads.com/list/show/7.Best_Books_of_the_21st_Century)
# Fetching books from list: Best Books of the 21st Century (https://www.goodreads.com/list/show/7.Best_Books_of_the_21st_Century)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Best Books of the 21st Century (9802 books)</title>\n\n<meta content=\'9,762 books based on 22730 votes: Harry Potter and the Deathly Hallows by J.K. Rowling, The Hunger Games by Suzanne Collins, The Kite Runner by Khaled Ho...\' name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/list/show/7.Best_Books_of_the_21st_Century\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "472-2220999-4462183";\n    var ue_id = "TA1NMBG4T39ZRWPNRS69";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:argume'
# Scraping page 3: https://www.goodreads.com/list/recently_active_lists?page=3
# Fetching books from list: Best Books of the 21st Century (https://www.goodreads.com/list/show/7.Best_Books_of_the_21st_Century)
# Fetching books from list: Best Books of the 21st Century (https://www.goodreads.com/list/show/7.Best_Books_of_the_21st_Century)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Best Books of the 21st Century (9802 books)</title>\n\n<meta content=\'9,762 books based on 22730 votes: Harry Potter and the Deathly Hallows by J.K. Rowling, The Hunger Games by Suzanne Collins, The Kite Runner by Khaled Ho...\' name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/list/show/7.Best_Books_of_the_21st_Century\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "063-6726881-7790963";\n    var ue_id = "SJ5J2HSNVFWFZY72HYWN";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:argume'
# Fetching books from list: Raine's Graphic Novels Collection (https://www.goodreads.com/list/show/151981.Raine_s_Graphic_Novels_Collection)
# Fetching books from list: Raine's Graphic Novels Collection (https://www.goodreads.com/list/show/151981.Raine_s_Graphic_Novels_Collection)
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>